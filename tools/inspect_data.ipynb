# %%
import openslide
import matplotlib.pyplot as plt

# %%
# %pwd

# %cd ..
# Out:
# /workspace/dp-code

# %%
slide = openslide.OpenSlide(".datasets/PKG - HistologyHSI-BC-Recurrence/01_01_Histological_Images/124.mrxs")
w, h = slide.dimensions

thumbnail = slide.get_thumbnail((2000,2000))
plt.imshow(thumbnail)
plt.axis("off")
# Out:
# (-0.5, 878.5, 1999.5, -0.5)
